# %% [markdown]
# # Alignment of cameras

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from copy import deepcopy
from pathlib import Path

import numpy as np
from dotenv import load_dotenv
from matplotlib import pyplot as plt
from rich import print

from collab_env.alignment import align
from collab_env.data.file_utils import expand_path, get_project_root
from collab_env.data.gcs_utils import GCSClient
from collab_env.utils import visualization as viz

from hloc.visualization import visualize_loc_from_log

# %% [markdown]
# ### Setup API keys

# %%
# Load environment variables from .env file
load_dotenv()
data_key = os.environ.get("COLLAB_DATA_KEY")

print(f"Data key: {data_key}")
# Out:
# Data key: ./config-local/collab-data-463313-c340ad86b28e.json

# %% [markdown]
# ### Download an RGB video

# %%
CURRENT_PROJECT = "COLLAB_DATA"
PROJECT_KEY = Path(os.environ.get(f"{CURRENT_PROJECT}_KEY"))  # type: ignore
PROJECT_ID = "-".join(PROJECT_KEY.stem.split("-")[:-1])

# Connect to GCS
gcs_client = GCSClient(
    project_id=PROJECT_ID,
    credentials_path=expand_path(PROJECT_KEY.as_posix(), get_project_root()),
)
# Out:
# 2025-08-18 20:23:10.171 | INFO     | collab_env.data.gcs_utils:__init__:35 - Using credentials from /Users/dima/git/collab-environment/config-local/collab-data-463313-c340ad86b28e.json
# 2025-08-18 20:23:10.173 | INFO     | collab_env.data.gcs_utils:__init__:41 - Using project collab-data-463313

# %% [markdown]
# Find all buckets and grab the videos for the desired session

# %%
CURRENT_SESSION = "2024_02_06"
CURRENT_BUCKET = gcs_client.list_buckets()[1]
DTYPE = "processed"

assert DTYPE in CURRENT_BUCKET, "Current bucket is not the processed bucket"

# Grab the aligned frames for the current session
current_session_dir = gcs_client.glob(f"{CURRENT_BUCKET}/{CURRENT_SESSION}*")[0]

# Set the current output directory
local_out_dir = get_project_root() / "data" / current_session_dir

print(f"Current session directory: {current_session_dir}")
print(f"Current output directory: {local_out_dir}")
# Out:
# Current session directory: fieldwork_processed/2024_02_06-session_0001
# Current output directory: /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001

# %% [markdown]
# Download aligned files and splat environment

# %%
splat_video = "C0043"
camera_id = "rgb_1"

required_files = [
    f"aligned_frames/{camera_id}/adjusted_{camera_id}.mp4",
    f"aligned_frames/{camera_id}/{camera_id}_tracked_bboxes.csv",
    f"environment/{splat_video}/preproc/colmap/", # entire folder
    f"environment/{splat_video}/preproc/images/", # entire folder
    f"environment/{splat_video}/rade-features/mesh/", # entire folder
    f"environment/{splat_video}/rade-features/2025-07-25_040743/dataparser_transforms.json"
]

# download all files/folders (check if folder by trailing slash)
for item in required_files:
    if item.endswith("/"):
        gcs_client.download_folder(
            f"{current_session_dir}/{item}",
            local_out_dir / item
        )
    else:
        gcs_client.download_file(
            f"{current_session_dir}/{item}",
            local_out_dir / item
        )
# Out:
# 2025-08-18 21:06:51.818 | INFO     | collab_env.data.gcs_utils:download_file:277 - File /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_frames/rgb_1/adjusted_rgb_1.mp4 already exists and overwrite is False. Skipping download.
# 2025-08-18 21:06:51.819 | INFO     | collab_env.data.gcs_utils:download_file:277 - File /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_frames/rgb_1/rgb_1_tracked_bboxes.csv already exists and overwrite is False. Skipping download.
# 2025-08-18 21:06:51.819 | INFO     | collab_env.data.gcs_utils:download_folder:220 - Downloading folder fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/colmap/ to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/colmap.
# 2025-08-18 21:06:51.923 | INFO     | collab_env.data.gcs_utils:download_folder:256 - Finished downloading folder fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/colmap/ to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/colmap.
# 2025-08-18 21:06:51.923 | INFO     | collab_env.data.gcs_utils:download_folder:220 - Downloading folder fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/images/ to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/images.
# 2025-08-18 21:06:52.057 | INFO     | collab_env.data.gcs_utils:download_folder:256 - Finished downloading folder fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/images/ to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/preproc/images.
# 2025-08-18 21:06:52.058 | INFO     | collab_env.data.gcs_utils:download_folder:220 - Downloading folder fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/mesh/ to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/mesh.
# 2025-08-18 21:06:52.102 | INFO     | collab_env.data.gcs_utils:download_folder:256 - Finished downloading folder fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/mesh/ to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/mesh.
# 2025-08-18 21:06:52.103 | INFO     | collab_env.data.gcs_utils:download_file:280 - Downloading file fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/2025-07-25_040743/dataparser_transforms.json to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/2025-07-25_040743/dataparser_transforms.json
# 2025-08-18 21:06:52.214 | INFO     | collab_env.data.gcs_utils:download_file:282 - Finished downloading file fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/2025-07-25_040743/dataparser_transforms.json to /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/environment/C0043/rade-features/2025-07-25_040743/dataparser_transforms.json.

# %%
# TODO: download ONLY what is needed!
# Download aligned frames and environment directories
# for dir_name in ["aligned_frames", "environment"]:
#     gcs_path = f"{current_session_dir}/{dir_name}"
#     local_path = local_out_dir / dir_name

#     # if not local_path.exists():
#     gcs_client.download_folder(gcs_path, local_path)

# %% [markdown]
# ## Aligning cameras
#
# To align the cameras, we require the following folders:
# 1. **aligned_dir:** spatiotemporally aligned RGB video to the thermal tracking
#
# 2. **environment_dir:** processed hloc + COLMAP information from collab-splats
#
# We load a video and sample frames (only really need one) which are then aligned to the camera poses used to fit the splats. Sampled frames are called *"queries"* and are localized within the splat scene.

# %%
# splat_video = "C0043"
# camera_id = "rgb_1"

# Directory containing the RGB-Thermal aligned video (maps to tracks)
aligned_dir = local_out_dir / "aligned_frames" / camera_id
aligned_video_fn = aligned_dir / f"adjusted_{camera_id}.mp4"

# Environment directory information -- contains the
environment_dir = local_out_dir / "environment"  # Path to environment directory
preproc_dir = (
    environment_dir / splat_video / "preproc"
)  # Path to colmap preproc directory
mesh_dir = environment_dir / splat_video / "rade-features" / "mesh"

# Outputs are written to aligned_splat dir keeping track of the query frames
output_dir = local_out_dir / "aligned_splat" / camera_id
query_dir = output_dir / "sampled-frames"

# %% [markdown]
# Load the RGB-Thermal aligned video and write frames to a directory

# %%
# Set the random seed to ensure same frame is sampled each time
np.random.seed(42)

frame_fns = align.extract_video_frames(
    video_path=aligned_video_fn, output_dir=query_dir, n_frames=1, method="random"
)

print(f"Extracted {len(frame_fns)} frames from {aligned_video_fn}:\n{frame_fns}")
# Out:
# Extracted 1 frames from /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_frames/rgb_1/adjusted_rgb_1.mp4:
# [PosixPath('/Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/sampled-frames/000860.png')]

# %% [markdown]
# Plot the frame to make sure things look okay

# %%
image = plt.imread(frame_fns[0])
plt.imshow(image)
plt.axis("off")
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %% [markdown]
# ### Localize a camera position
#
# Internally, we use hloc to extract features from the query images and match these features to the images used to build the splat

# %%
# Align the new camera to the COLMAP fit
localized_poses, logs, viz_info = align.align_to_colmap(
    preproc_dir=preproc_dir,
    query_dir=query_dir,
    output_dir=output_dir,
    return_logs=True,  # Returns logs + viz info for visualization otherwise would only return poses
)
# Out:
# Creating output directory...
# [2025/08/18 20:48:50 hloc INFO] Extracting local features with configuration:
# {'model': {'max_keypoints': 4096, 'name': 'superpoint', 'nms_radius': 3},
#  'output': 'feats-superpoint-n4096-r1024',
#  'preprocessing': {'grayscale': True, 'resize_max': 1024}}
# Extracting features from queries and matching...
# Loaded SuperPoint model
# 100%|██████████| 1/1 [00:06<00:00,  6.93s/it]
# [2025/08/18 20:48:57 hloc INFO] Finished exporting features.
# [2025/08/18 20:48:57 hloc INFO] Found 597 pairs.
# [2025/08/18 20:48:57 hloc INFO] Matching local features with configuration:
# {'model': {'name': 'superglue',
#            'sinkhorn_iterations': 50,
#            'weights': 'outdoor'},
#  'output': 'matches-superglue'}
# Loaded SuperGlue model ("outdoor" weights)
# 100%|██████████| 597/597 [04:59<00:00,  1.99it/s]
# [2025/08/18 20:53:57 hloc INFO] Finished exporting matches.
# Localizing query images...: 100%|██████████| 1/1 [00:01<00:00,  1.52s/it]

# %%
print(localized_poses)
# Out:
# [
#     {
#         'cam_from_world': Rigid3d(rotation_xyzw=[-0.0497264, -0.217046, -0.0829716, 0.971357],
# translation=[2.79607, -0.13197, -0.187786]),
#         'num_inliers': 1989,
#         'inlier_mask': array([False, False, False, ..., False,  True, False]),
#         'camera': Camera(camera_id=Invalid, model=SIMPLE_RADIAL, width=640, height=480, params=[1193.83, 320, 240,
# -1.78669] (f, cx, cy, k))
#     }
# ]

# %% [markdown]
# Running this function returns the camera parameters aligned to the COLMAP cameras. We can visualize the quality of this alignment using the hloc toolbox
#
# **(Left)** Query image
#
# **(Right)** Best match original pose

# %%
# Grab the log from the first query image
query_logs = logs[0]

# Visualize the localization results
visualize_loc_from_log(
    image_dir=query_logs["query"].parent,
    query_name=query_logs["query"].name,
    loc=query_logs["loc"],
    top_k_db=1,  # Only show the target image and the best match
    **viz_info,  # Contains the directory of original images + the colmap model
)

# %% [markdown]
# Align the localization to the mesh

# %%
# Grab the localized pose
pose = localized_poses[0]

# Extract camera information from that pose and format --> this alpha needs to be tuned
camera_params = align.extract_camera_params(pose, alpha=0)

# Align the camera to the mesh and save
aligned_camera_params = align.align_to_mesh(
    camera_params=camera_params,
    mesh_dir=mesh_dir,
    out_fn=output_dir / f"{camera_id}_mesh-aligned.pkl",
)

# %% [markdown]
# #### optional - upload to processed folder

# %%
gcs_client.upload_folder(
    local_path=local_out_dir / "aligned_splat/",
    gcs_path=f"{current_session_dir}/aligned_splat"
)
# Out:
# 2025-08-18 21:11:55.905 | INFO     | collab_env.data.gcs_utils:upload_folder:195 - Uploading folder /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat to fieldwork_processed/2024_02_06-session_0001/aligned_splat.
# 2025-08-18 21:11:55.906 | INFO     | collab_env.data.gcs_utils:upload_file:180 - Uploading file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/matches.h5 to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/matches.h5.
# 2025-08-18 21:12:05.495 | INFO     | collab_env.data.gcs_utils:upload_file:182 - Uploaded file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/matches.h5 to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/matches.h5.
# 2025-08-18 21:12:05.496 | INFO     | collab_env.data.gcs_utils:upload_file:180 - Uploading file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/pairs-loc.txt to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/pairs-loc.txt.
# 2025-08-18 21:12:05.788 | INFO     | collab_env.data.gcs_utils:upload_file:182 - Uploaded file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/pairs-loc.txt to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/pairs-loc.txt.
# 2025-08-18 21:12:05.789 | INFO     | collab_env.data.gcs_utils:upload_file:180 - Uploading file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/features.h5 to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/features.h5.
# 2025-08-18 21:12:29.987 | INFO     | collab_env.data.gcs_utils:upload_file:182 - Uploaded file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/features.h5 to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/features.h5.
# 2025-08-18 21:12:29.988 | INFO     | collab_env.data.gcs_utils:upload_file:180 - Uploading file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/rgb_1_mesh-aligned.pkl to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/rgb_1_mesh-aligned.pkl.
# 2025-08-18 21:12:30.259 | INFO     | collab_env.data.gcs_utils:upload_file:182 - Uploaded file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/rgb_1_mesh-aligned.pkl to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/rgb_1_mesh-aligned.pkl.
# 2025-08-18 21:12:30.260 | INFO     | collab_env.data.gcs_utils:upload_file:180 - Uploading file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/sampled-frames/000860.png to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/sampled-frames/000860.png.
# 2025-08-18 21:12:30.632 | INFO     | collab_env.data.gcs_utils:upload_file:182 - Uploaded file /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/sampled-frames/000860.png to fieldwork_processed/2024_02_06-session_0001/aligned_splat/rgb_1/sampled-frames/000860.png.
# 2025-08-18 21:12:30.633 | INFO     | collab_env.data.gcs_utils:upload_folder:205 - Finished uploading folder /Users/dima/git/collab-environment/data/fieldwork_processed/2024_02_06-session_0001/aligned_splat to fieldwork_processed/2024_02_06-session_0001/aligned_splat.

# %% [markdown]
# #### Optional visualizations and metrics

# %% [markdown]
# Visualize camera perspective of the mesh

# %%
# Get out mesh filename
mesh_fn = mesh_dir / "mesh.ply"

# Copy the parameters and format for pyvista
pv_camera = deepcopy(aligned_camera_params)
pv_viz_kwargs = viz.format_pyvista_camera_params(pv_camera)

# Visualize the camera view
plotter = viz.visualize_splat(
    mesh_fn.as_posix(),
    mesh_kwargs=viz.MESH_KWARGS,
    viz_kwargs=pv_viz_kwargs,
)

# Render the camera view as an image
view_image = plotter.screenshot(return_img=True)
plt.imshow(view_image)  # type: ignore
plt.axis("off")
# Out:
# (-0.5, 639.5, 479.5, -0.5)

# %% [markdown]
# Compute the similarity between the viewed image and ground truth

# %%
frame = plt.imread(frame_fns[0])

result = align.compute_image_similarity(
    view_image=view_image,  # type: ignore
    frame=frame,
)

comparison_plot = align.visualize_comparison(
    view_image=view_image,
    frame=frame,
    result=result,
)
# Out:
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /Users/dima/git/collab-environment/.venv-310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/dima/git/collab-environment/.venv-310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/alexnet-owt-7be5be79.pth" to /Users/dima/.cache/torch/hub/checkpoints/alexnet-owt-7be5be79.pth
# 100%|██████████| 233M/233M [00:02<00:00, 90.4MB/s]
# Loading model from: /Users/dima/git/collab-environment/.venv-310/lib/python3.10/site-packages/lpips/weights/v0.1/alex.pth

# %% [markdown]
# Show camera position on mesh

# %%
# Create custom camera kwargs to apply to the visualization
camera_kwargs = viz.CAMERA_KWARGS.copy()

# These format the camera frustum visualization
camera_kwargs["line_width"] = 5
camera_kwargs["scale"] = 0.025
camera_kwargs["opacity"] = 0.9
camera_kwargs["color"] = [0.9, 0.9, 0.9]
camera_kwargs["show_axes"] = True

# Grab our localized camera's pose
poses = [pv_camera["c2w"]]

# Visualize the splat
plotter = viz.visualize_splat(
    mesh_fn.as_posix(),
    poses,
    mesh_kwargs=viz.MESH_KWARGS,
    viz_kwargs=viz.VIZ_KWARGS,
    camera_kwargs=camera_kwargs,
)

mesh_image = plotter.screenshot(window_size=(800, 800), return_img=True)
plt.imshow(mesh_image)  # type: ignore
plt.axis("off")
# Out:
# (-0.5, 799.5, 799.5, -0.5)
